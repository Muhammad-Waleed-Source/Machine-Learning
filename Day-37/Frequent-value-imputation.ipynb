# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Waleed-Source/Machine-Learning/blob/main/Day-37/Frequent-value-imputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head()

# %%
df.isnull().mean()*100

# %%
df['GarageQual'].value_counts().plot(kind='bar')
