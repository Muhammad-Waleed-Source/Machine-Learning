# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Waleed-Source/Machine-Learning/blob/main/Day-50/LR-Mathematical-Formulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class MyLR:
  def __init__(self):
    self.m = None
    self.b - None

  def fit(self, X_train, y_train):
    pass

  def predict(self, X_test):
    pass

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
